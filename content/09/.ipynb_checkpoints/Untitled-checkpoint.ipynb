# %%
import plotly.graph_objects as go
import pandas as pd

df = pd.read_csv('supp.csv')
df.columns = ['Name','URL', 'About', 'Class', 'D', 'DOI']

# fig = go.Figure(data=[go.Table(
#     header=dict(values=list(df.columns),
#                 fill_color='paleturquoise',
#                 align='left'),
#     cells=dict(values=[df.X,df.A, df.B, df.C, df.D, df.E],
#                fill_color='lavender',
#                align='left'))
# ])

fig = go.Figure(go.Table(header={"values": df.columns}, cells={"values": df.T.values}))

fig.update_layout(
    updatemenus=[
        {
            "buttons": [
                {
                    "label": c,
                    "method": "update",
                    "args": [
                        {
                            "cells": {
                                "values": df.T.values
                                if c == "Type"
                                else df.loc[df["Class"].eq(c)].T.values
                            }
                        }
                    ],
                }
                for c in ["All"] + df["Class"].unique().tolist()
            ]
        }
    ]
)

fig.show()
# Out:
# <div>                            <div id="b99f5b2b-d9a7-4f7e-aa41-726dcc8dae11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b99f5b2b-d9a7-4f7e-aa41-726dcc8dae11")) {                    Plotly.newPlot(                        "b99f5b2b-d9a7-4f7e-aa41-726dcc8dae11",                        [{"cells": {"values": [[null, "2.1. Study Preparation and Piloting", "protocols.io", "Protocol exchange", "Nature protocols", "Example SOP for MRI", "Example SOP for EEG", "SOP of the HCP for MRI", "SOP of the HCP for MEG", "BrainVerse", "Hitchhackers", "BrainPower", null, "2.2. Pre-registration ", "OSF prepregistration", "Aspredicted.org", "Clinicaltrials.gov", "Center for Open Science (Preregistration)", "Center for Open Science (Registered Reports)", "Tips for pre-registrations (from OHBM)", "fmri-prereg", "EEG ERP Preregistration Template", "List of pre-registration examples", "Examples of preregistered M/EEG studies", "[See Reporting section in 6.4. Publication of scientific results]", null, "2.3. Ethical review and data sharing plan ", "Open Brain Consent", "TTW: Guide for Ethical Research", null, "2.4. Looking at the data early and ofter: Monitoring quality", "MRIQC", "qoala-T", "visual QC", null, "3. Data acquisition", null, "3.1. Brain data acquisition and reconstruction", "Open Source Imaging", "MRhub", "qmrLab", "Pulseq", "PyPulseq", "GammaStar", "TOPPE", "ODIN", "SequenceTree", "ISMSM Raw data format", "Gadgetron", "BART", "MRIReco.jl", "Vendor-neutral sequences (VENUS)", "SigPy", "MRM Highlights", "MNE-Python Maxwell filter", "OpenBCI", null, "3.2. Stimulus presentation and behaviour", "Psychopy", "Psychtoolbox", "Pavlovia", "ReproStim", "ERP CORE", null, "4. Research Data Management ", null, "4.1. Data standard: BIDS", "BIDS", "BIDS specification", "BIDS validator", "BIDS starter kit", "BIDS examples", "BIDS converters", "BIDS available converters", "HeuDiConv", "dcm2bids", "Data2Bids", "ReproIn", "PET2BIDS", "MNE-BIDS", "Fieldtrip data2bids", "Brainstorm BIDS tools", "EEGLAB bids-matlab-tools", "Interaction with BIDS datasets", "pyBIDS", "BIDS-Matlab", "rbids", "ancpBIDS", "BIDS apps", "Interaction with the BIDS community", "BIDS email discussion list", "Neurostars: BIDS tag", "Brainhack Mattermost: BIDS channel", null, "4.2. Metadata and data annotation", "Hierarchical Event Descriptor (HED)", "InterLex", "The Cognitive Atlas", "The Cognitive Paradigm Ontology (CogPO)", "PROV vocabulary", "The Neuroimaging Data Modeling (NIDM)", "NIDM-Terms", "PyNIDM", null, "4.3. Data management and tracking", "DMP Online", "DataLad", "DataLad Handbook", "Brainlife", "XNAT", null, "5. Data processing and analysis", null, "5.1. Software as a research instrument", "General", "Nibabel", "NiPype", "The Good Research Code Handbook", "Neuroimaging and data science Book", "Python for the practicing neuroscientist", "[See 6.2. Methodological transparency]", "Neuroimaging MRI", "AFNI", "ANTs", "Freesurfer", "FSL", "SPM", "Neuroimaging MEG & EEG", "Brainstorm", "EEGLAB", "Fieldtrip", "MNE-Python", "Neuroimaging PET", "PETSurfer", "Kinfitr", "PETPVE12", null, "5.2. Standardized preprocessing and workflows", "NIpreps", "fMRIprep", "HCP Pipelines", "C-PAC", "QSIPREP", "Connectome Mapper", "TractoFlow", "NIAK", "Neurosynth", "BrainMap", "NiMARE", "neuroquery", "qMRFlow", "Appian", "MNE-BIDS Pipeline", "Containers", "Docker", "Apptainer/Singularity", "NeuroDocker", "ReproMan", null, "5.3. Statistical modeling and advanced analysis", "scikit-learn", "Nilearn", "PyMVPA", "Neuroscout", "FitLins", "BIDS-SM", null, "5.4. Multiverse analysis", "Explorable Multiverse Analyses", "Fuzzy", "boba", "Neuroimaging Analysis Replication & Prediction Study (NARPS)", "EEGManyPipelines", "Data driven auditory encoding", null, "6. Research  ...

# %%
# Out:
#                        2. Study inception and planning  \
# 0                                                  NaN
# 1                  2.1. Study Preparation and Piloting
# 2                                         protocols.io
# 3                                    Protocol exchange
# 4                                     Nature protocols
# ..                                                 ...
# 275                                           ReproNim
# 276  Framework for Open Reprod Research Training (F...
# 277      The Declaration on Research Assessment (DORA)
# 278                               Awesome Neuroscience
# 279                                              RIOTS
#
#                                             Unnamed: 1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                             https://www.protocols.io
# 3          https://protocolexchange.researchsquare.com
# 4                         https://www.nature.com/nprot
# ..                                                 ...
# 275                          https://www.repronim.org/
# 276                                 https://forrt.org/
# 277                                https://sfdora.org/
# 278  https://github.com/analyticalmonk/awesome-neur...
# 279                                                NaN
#
#                                             Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                       Platform for sharing protocols    General        Yes
# 3      Repository for sharing protocols sponsored b...    General        Yes
# 4      Journal to publish secondary research articl...    General        Yes
# ..                                                 ...        ...        ...
# 275    Reproducible analyses framework (data, softw...        MRI        Yes
# 276    Framework for Open and Reproducible Research...    General         No
# 277    Initiative to improve the ways in which rese...    General         No
# 278    Curated list of awesome neuroscience librari...    General         No
# 279                                                NaN        NaN        NaN
#
#     Unnamed: 5
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 275        NaN
# 276        NaN
# 277        NaN
# 278        NaN
# 279        NaN
#
# [280 rows x 6 columns]
